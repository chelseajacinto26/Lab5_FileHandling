# %%
# 1 Create and Write to a File
from pathlib import Path

student_id = "2025-1305"
student_name = "Lee Anne Chelsea F. Jacinto"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!")

print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\Dawn\Documents\Activity_5_Files\intro_2025-1305.txt

# %%
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_{student_id}.txt"

content = file_path.read_text()
print(content)
# Out:
# Welcome Lee Anne Chelsea F. Jacinto (ID: 2025-1305) to File Handling in Python!

# %%
from pathlib import Path

student_id = "2025-1305"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

with file_path.open("a") as f:
    f.write("\nThis is a new line.")

print(f"Line appended to: {file_path}")
# Out:
# Line appended to: C:\Users\Dawn\Documents\Activity_5_Files\intro_2025-1305.txt

# %%
from pathlib import Path

student_id = "2025-1305"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"intro_{student_id}.txt"

with file_path.open("a") as f:
    f.write("\nThis is a new line.")

print(f"Line appended to: {file_path}")
# Out:
# Line appended to: C:\Users\Dawn\Documents\Activity_5_Files\intro_2025-1305.txt

# %%
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"lines_{student_id}.txt"

file_path.write_text("Line 1\nLine 2\nLine 3")
print("File created.")
# Out:
# File created.

# %%
from pathlib import Path

student_id = "2025-1305"
student_name = "Lee Anne Chelsea F. Jacinto"

file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

text = file_path.read_text()
word_count = len(text.split())

print(f"{student_name} (ID: {student_id}) - Word count in file '{file_path.name}': {word_count}")
# Out:
# Lee Anne Chelsea F. Jacinto (ID: 2025-1305) - Word count in file 'lines_2025-1305.txt': 6

# %%
# Cell 1: Create and Write to a File
from pathlib import Path

student_id = "2025-1305"
student_name = "Lee Anne Chelsea F. Jacinto"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
documents_path.mkdir(parents=True, exist_ok=True)

file_path = documents_path / f"intro_{student_id}.txt"
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!")

print(f"File created and text written at: {file_path}")

# Cell 2: Copy File
import shutil
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

# Define source and destination
src = documents_path / f"intro_{student_id}.txt"
dst = documents_path / f"intro_copy_{student_id}.txt"

# Copy file
shutil.copy(src, dst)

print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File created and text written at: C:\Users\Dawn\Documents\Activity_5_Files\intro_2025-1305.txt
# File copied successfully from intro_2025-1305.txt to intro_copy_2025-1305.txt.

# %%
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"

old_file = documents_path / f"intro_copy_{student_id}.txt"
new_file = documents_path / f"intro_renamed_{student_id}.txt"

# FIX: remove target file if it already exists
if new_file.exists():
    new_file.unlink()

old_file.rename(new_file)

print(f"File renamed successfully from {old_file.name} to {new_file.name}.")
# Out:
# File renamed successfully from intro_copy_2025-1305.txt to intro_renamed_2025-1305.txt.

# %%
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"intro_renamed_{student_id}.txt"

if file_path.exists():
    file_path.unlink()
    print("File deleted successfully.")
else:
    print("No file found to delete.")
# Out:
# File deleted successfully.

# %%
from pathlib import Path

student_id = "2025-1305"

documents_path = Path.home() / "Documents" / "Activity_5_Files"
new_dir = documents_path / f"data_{student_id}"

new_dir.mkdir(parents=True, exist_ok=True)

print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: C:\Users\Dawn\Documents\Activity_5_Files\data_2025-1305

# %%
import json
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define directory and file path
documents_path = Path.home() / "Documents" / "Activity_5_Files"
data_dir = documents_path / f"data_{student_id}"
data_dir.mkdir(parents=True, exist_ok=True)

# Sample data
data = {"name": "Lee Anne Chelsea F. Jacinto", "19": 21, "BSECE": "Python Programming"}

# Write JSON file
file_path = data_dir / f"student_{student_id}.json"

with file_path.open("w") as f:
    json.dump(data, f, indent=4)

print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: C:\Users\Dawn\Documents\Activity_5_Files\data_2025-1305\student_2025-1305.json

# %%
import json
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define the path to the JSON file
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"data_{student_id}" / f"student_{student_id}.json"

# FIX: check if file exists before reading
if file_path.exists():
    with file_path.open("r") as f:
        data = json.load(f)
    print(data)
else:
    print("JSON file not found.")
# Out:
# {'name': 'Lee Anne Chelsea F. Jacinto', '19': 21, 'BSECE': 'Python Programming'}

# %%
import csv
from pathlib import Path

# Personal details
student_id = "2025-1305"
student_name = "Lee Anne Chelsea F. Jacinto"

# Define directory and file path
# Fixed the line breaks here
documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"students_{student_id}.csv"

# Ensure the directory exists before writing to it
documents_path.mkdir(parents=True, exist_ok=True)

# Sample data to write
rows = [
    ["Name", "Student ID", "Score"],
    ["Anna", "2025-1001", 90],
    ["Ben", "2025-1002", 85],
    [student_name, student_id, 95]
]

# Write CSV file
with file_path.open("w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"CSV file created at: {file_path}")
# Out:
# CSV file created at: C:\Users\Dawn\Documents\Activity_5_Files\students_2025-1305.csv

# %%
import csv
from pathlib import Path

# Updated Personal details
student_id = "2025-1305"
student_name = "Your Full Name"

# Define directory and file path
documents_path = Path.home() / "Documents" / "Activity_5_Files"
file_path = documents_path / f"students_{student_id}.csv"

# Ensure the directory exists
documents_path.mkdir(parents=True, exist_ok=True)

# Sample data
rows = [
    ["Name", "Student ID", "Score"],
    ["Anna", "2025-1001", 90],
    ["Ben", "2025-1002", 85],
    [student_name, student_id, 95]
]

# Write CSV file
with file_path.open("w", newline='') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"Success! CSV file created at: {file_path}")
# Out:
# Success! CSV file created at: C:\Users\Dawn\Documents\Activity_5_Files\students_2025-1305.csv

# %%
from pathlib import Path

# Updated Personal details
student_id = "2025-1305"

# Define a path to a file that does not exist
# Fixed the line break error here
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"missing_file_{student_id}.txt"

# Attempt to read the file and handle error
try:
    # This line will trigger the FileNotFoundError
    content = file_path.read_text()
    print(content)
except FileNotFoundError:
    # This block catches the error and runs instead of crashing
    print(f"Error: File not found for Student ID: {student_id}")
    print(f"Path searched: {file_path}")
# Out:
# Error: File not found for Student ID: 2025-1305
# Path searched: C:\Users\Dawn\Documents\Activity_5_Files\missing_file_2025-1305.txt

# %%
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define directory path
documents_path = Path.home() / "Documents" / "Activity_5_Files"

# Ensure the directory exists so the script doesn't error out
if documents_path.exists():
    # Find all .txt files in the directory using glob
    # "*.txt" means: match anything ending in .txt
    txt_files = list(documents_path.glob("*.txt"))

    # Display count and file names
    print(f"Student ID: {student_id}")
    print(f"Found {len(txt_files)} .txt files in {documents_path}")
    
    if txt_files:
        print("File list:")
        for file in txt_files:
            print(f"- {file.name}")
    else:
        print("No .txt files found in this directory.")
else:
    print(f"Directory not found: {documents_path}")
# Out:
# Student ID: 2025-1305
# Found 4 .txt files in C:\Users\Dawn\Documents\Activity_5_Files
# File list:
# - intro_2025-1305.txt
# - intro_2025-XXXX.txt
# - lines_2025-1305.txt
# - lines_2025-XXXX.txt

# %%
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define directory path
documents_path = Path.home() / "Documents" / "Activity_5_Files"

# Ensure the directory exists so the script doesn't error out
if documents_path.exists():
    # Find all .txt files in the directory using glob
    # "*.txt" means: match anything ending in .txt
    txt_files = list(documents_path.glob("*.txt"))

    # Display count and file names
    print(f"Student ID: {student_id}")
    print(f"Found {len(txt_files)} .txt files in {documents_path}")
    
    if txt_files:
        print("File list:")
        for file in txt_files:
            print(f"- {file.name}")
    else:
        print("No .txt files found in this directory.")
else:
    print(f"Directory not found: {documents_path}")
# Out:
# Student ID: 2025-1305
# Found 4 .txt files in C:\Users\Dawn\Documents\Activity_5_Files
# File list:
# - intro_2025-1305.txt
# - intro_2025-XXXX.txt
# - lines_2025-1305.txt
# - lines_2025-XXXX.txt

# %%
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define file path (Fixed the line break errors)
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

# Ensure directory exists first
file_path.parent.mkdir(parents=True, exist_ok=True)

# Ensure file exists before reading
if not file_path.exists():
    sample_lines = ["apple", "banana", "cherry"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")

# Read, process, and rewrite the file
lines = file_path.read_text().splitlines()

with file_path.open("w") as f:
    for i, line in enumerate(lines, 1):
        # .upper() makes it uppercase, i is the counter starting at 1
        f.write(f"{i}: {line.upper()}\n")

print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: C:\Users\Dawn\Documents\Activity_5_Files\lines_2025-1305.txt

# %%
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define file path
file_path = Path.home() / "Documents" / "Activity_5_Files" / f"lines_{student_id}.txt"

# Ensure directory exists
file_path.parent.mkdir(parents=True, exist_ok=True)

# Ensure file exists before processing
if not file_path.exists():
    sample_lines = ["Line 1", "Line 2", "Line 3"]
    file_path.write_text("\n".join(sample_lines))
    print(f"Sample file created for Student ID: {student_id}")

# Read, reverse, and overwrite the file
lines = file_path.read_text().splitlines()

# Reverse the list order
lines.reverse()

# Write the reversed lines back to the file
with file_path.open("w") as f:
    f.write("\n".join(lines) + "\n")

print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: 2025-1305

# %%
from pathlib import Path

# Personal details
student_id = "2025-1305"

# Define file paths
documents_path = Path.home() / "Documents" / "Activity_5_Files"
f1 = documents_path / f"intro_{student_id}.txt"
f2 = documents_path / f"lines_{student_id}.txt"
merged = documents_path / f"merged_{student_id}.txt"

# Ensure the directory exists
documents_path.mkdir(parents=True, exist_ok=True)

# Ensure both source files exist
if not f1.exists():
    f1.write_text(f"Welcome {student_id} to File Handling in Python!")
    print(f"Sample intro file created for Student ID: {student_id}")

if not f2.exists():
    f2.write_text("Line 1\nLine 2\nLine 3")
    print(f"Sample lines file created for Student ID: {student_id}")

# Merge contents of both files
# Using "w" (write) mode for the merged file
with merged.open("w") as mf:
    mf.write(f1.read_text())  # Pulls text from the intro file
    mf.write("\n---\n")       # Adds a separator for clarity
    mf.write(f2.read_text())  # Pulls text from the lines file

print(f"Files merged successfully for Student ID: {student_id}")
print(f"Check your merged file at: {merged}")
# Out:
# Files merged successfully for Student ID: 2025-1305
# Check your merged file at: C:\Users\Dawn\Documents\Activity_5_Files\merged_2025-1305.txt
