# %%
# 1. Writing to a File
from pathlib import Path

output_dir = Path.home() / "Documents" / "PythonFiles"
output_dir.mkdir(exist_ok=True)

file_path = output_dir / "Act5_example.txt"

with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.")

print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\Dawn\Documents\PythonFiles\Act5_example.txt

# %%
# 2. Reading from a File
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    print("File content:\n", content)

with open(file_path, "r", encoding="utf-8") as file:
    for line_number, line in enumerate(file, 1):
        print(f"Line {line_number}: {line.strip()}")
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.
# Line 1: Hello, Welcome to Python Programming!
# Line 2: File saved safely with pathlib.

# %%
# 3. Appending Data
with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")

print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
# 4. Safe File Operations with Backup
from datetime import datetime
import shutil
from pathlib import Path

backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True)

def write_with_backup(filename: str, content: str):
    file_path = backup_dir / filename

    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_path = file_path.with_name(
            f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
        )
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")

    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)
        print(f"File saved: {file_path.name}")

def read_file(filename: str):
    file_path = backup_dir / filename
    with open(file_path, "r", encoding="utf-8") as file:
        return file.read()

print("=== File Operations Demo ===")
print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

print("\n3. Reading file:")
print(read_file("demo.txt"))

print("\n4. Listing backups:")
for backup in backup_dir.glob("*backup*"):
    print("-", backup.name)
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# Backup saved: demo_backup_20260416_011625.txt
# File saved: demo.txt
#
# 2. Updating file (with backup):
# Backup saved: demo_backup_20260416_011625.txt
# File saved: demo.txt
#
# 3. Reading file:
# Updated content
#
# 4. Listing backups:
# - demo_backup_20260416_011428.txt
# - demo_backup_20260416_011625.txt

# %%
# 5. Menu-Driven File Manager
from pathlib import Path
from datetime import datetime
import shutil

backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(parents=True, exist_ok=True)

def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ").strip()

    # ✅ FIX 1: Prevent empty filename
    if not file_name:
        print("Error: Filename cannot be empty.")
        return

    # ✅ FIX 2: Ensure it is a file (add .txt if missing)
    if "." not in file_name:
        file_name += ".txt"

    file_path = backup_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")

        choice = input("Choose an option (1-5): ")

        if choice == "1":
            content = input("Enter content:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")

        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")

        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")

        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")

        elif choice == "5":
            print("Exiting...")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Content appended.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# File written successfully.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Content appended.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Content appended.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
